# %% [markdown]
# <a href="https://colab.research.google.com/github/Nore-gibhub/Challenge3_TelecomX_part2/blob/main/challenge3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df_datos = pd.read_csv('/content/datos_TelecomX_tratados.csv')
df_datos.head()
# Out:
#    customerID Churn customer_gender  customer_SeniorCitizen customer_Partner  \
# 0  0004-TLHLJ   Yes            Male                       0               No
# 1  0011-IGKFF   Yes            Male                       1              Yes
# 2  0013-EXCHZ   Yes          Female                       1              Yes
# 3  0022-TCJCI   Yes            Male                       1               No
# 4  0023-HGHWL   Yes            Male                       1               No
#
#   customer_Dependents  customer_tenure account_Contract  \
# 0                  No                4   Month-to-month
# 1                  No               13   Month-to-month
# 2                  No                3   Month-to-month
# 3                  No               45         One year
# 4                  No                1   Month-to-month
#
#   account_PaperlessBilling    account_PaymentMethod  account_Charges.Monthly  \
# 0                      Yes         Electronic check                     73.9
# 1                      Yes         Electronic check                     98.0
# 2                      Yes             Mailed check                     83.9
# 3                       No  Credit card (automatic)                     62.7
# 4                      Yes         Electronic check                     25.1
#
#    account_Charges.Total    tipo_de_servicio valor
# 0                 280.85  phone_PhoneService   Yes
# 1                1237.85  phone_PhoneService   Yes
# 2                 267.40  phone_PhoneService   Yes
# 3                2791.50  phone_PhoneService   Yes
# 4                  25.10  phone_PhoneService   Yes

# %%
df_datos.shape
# Out:
# (15973, 14)

# %%
df_datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15973 entries, 0 to 15972
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customerID                15973 non-null  object
#  1   Churn                     15973 non-null  object
#  2   customer_gender           15973 non-null  object
#  3   customer_SeniorCitizen    15973 non-null  int64
#  4   customer_Partner          15973 non-null  object
#  5   customer_Dependents       15973 non-null  object
#  6   customer_tenure           15973 non-null  int64
#  7   account_Contract          15973 non-null  object
#  8   account_PaperlessBilling  15973 non-null  object
#  9   account_PaymentMethod     15973 non-null  object
#  10  account_Charges.Monthly   15973 non-null  float64
#  11  account_Charges.Total     15973 non-null  float64
#  12  tipo_de_servicio          15973 non-null  object
#  13  valor                     15973 non-null  object
# dtypes: float64(2), int64(2), object(10)
# memory usage: 1.7+ MB
